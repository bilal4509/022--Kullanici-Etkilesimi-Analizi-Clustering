# %% [markdown]
# <img src='11.png'>

# %% [raw]
# Kullanıcı Etkileşimi Analizi, bir ürün, hizmet veya platformla ilgili kullanıcı katılımını, etkileşimini ve memnuniyetini değerlendirmek ve anlamak için veriye dayalı bir yaklaşımdır. Kullanıcı davranışı ve tercihleri hakkında fikir edinmek için çeşitli ölçümlerin ve davranış kalıplarının analiz edilmesini içerir. İşletmelerin kullanıcı deneyimini geliştirmek, pazarlama stratejilerini optimize etmek ve genel ürün veya hizmet performansını iyileştirmek için bilinçli kararlar almasına yardımcı olur

# %%
#Auto_ML ile sınıflandırma ve çözüm yapacağız

# %%
#pip install pycaret

# %%
import pandas as pd

# %%
df=pd.read_csv('bounce-rate.csv')

# %%
df.head()
# Out:
#       Client ID  Sessions Avg. Session Duration Bounce Rate
# 0  5.778476e+08       367              00:01:35      87.19%
# 1  1.583822e+09       260              00:01:04      29.62%
# 2  1.030699e+09       237              00:00:02      99.16%
# 3  1.025030e+09       226              00:02:22      25.66%
# 4  1.469968e+09       216              00:01:23      46.76%

# %%
# Clustering

# %%
df.head()
# Out:
#       Client ID  Sessions Avg. Session Duration Bounce Rate
# 0  5.778476e+08       367              00:01:35      87.19%
# 1  1.583822e+09       260              00:01:04      29.62%
# 2  1.030699e+09       237              00:00:02      99.16%
# 3  1.025030e+09       226              00:02:22      25.66%
# 4  1.469968e+09       216              00:01:23      46.76%

# %%
from pycaret.clustering import*

# %%
setup(df)
# Out:
# <style type="text/css">
# #T_5a3e3_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5a3e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a3e3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5a3e3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a3e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5a3e3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5a3e3_row0_col1" class="data row0 col1" >8231</td>
#     </tr>
#     <tr>
#       <th id="T_5a3e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5a3e3_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_5a3e3_row1_col1" class="data row1 col1" >(999, 4)</td>
#     </tr>
#     <tr>
# ...

# %%
kmeans=create_model('kmeans',4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_507dd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_507dd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_507dd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_507dd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_507dd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_507dd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_507dd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_507dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_507dd_row0_col0" class="data row0 col0" >0.5941</td>
#       <td id="T_507dd_row0_col1" class="data row0 col1" >5043.7253</td>
# ...

# %%
plot_model(kmeans)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(kmeans,plot='elbow')

# %%
plot_model(kmeans,plot='tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
